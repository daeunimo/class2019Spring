# %%
# description
# https://www.kaggle.com/c/boston-housing

# TensorFlow and tf.keras
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = tensorflow.keras.datasets.boston_housing.load_data(path='boston_housing.npz')

# %%
model = Sequential()
model.add(Dense(10, input_shape=[13], activation = 'relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(30, activation='relu'))
model.add(Dense(40, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(60, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='rmsprop', loss='mse')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_18 (Dense)             (None, 10)                140
# _________________________________________________________________
# dense_19 (Dense)             (None, 20)                220
# _________________________________________________________________
# dense_20 (Dense)             (None, 30)                630
# _________________________________________________________________
# dense_21 (Dense)             (None, 40)                1240
# _________________________________________________________________
# dense_22 (Dense)             (None, 50)                2050
# _________________________________________________________________
# dense_23 (Dense)             (None, 60)                3060
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 61
# ...
# Total params: 7,401
# ...

# %%
print(model.input_shape) # None 부분은 데이터의 개수에 따라 달라질 수 있음. -> 정해지지 않음. = batch_size
print(model.output_shape)
# Out:
# (None, 13)
# (None, 1)

# %% [markdown]
# ### None = batch_size?

# %%
# epoch: 전체 데이터 셋에 대해 몇 번 학습을 시키는가?
    # epoch값이 너무 작다면, underfitting이, 너무 크다면 overfitting이 발생할 확률이 높음
# batch size: 한 번의 반복마다 나눠지는 데이터 샘플의 size

# %%
model.fit(x_train, y_train, epochs=1200, batch_size=20) #batch_size의 defalt는 32 #데이터를 쪼개서 학습시키는 것
#1일 경우, 속도가 느림 #404인 경우, 속도가 빠름. but, loss가 잘 줄어들지 않음 #속도와 정확도에 따라 선택
# Out:
# Epoch 1/1200
# 404/404 [==============================] - 0s 84us/sample - loss: 14.8467
# Epoch 2/1200
# 404/404 [==============================] - 0s 173us/sample - loss: 13.0909
# Epoch 3/1200
# 404/404 [==============================] - 0s 186us/sample - loss: 14.6877
# Epoch 4/1200
# 404/404 [==============================] - 0s 94us/sample - loss: 12.7647
# Epoch 5/1200
# 404/404 [==============================] - 0s 99us/sample - loss: 17.2817
# Epoch 6/1200
# 404/404 [==============================] - 0s 101us/sample - loss: 12.0870
# Epoch 7/1200
# 404/404 [==============================] - 0s 136us/sample - loss: 17.2356
# Epoch 8/1200
# 404/404 [==============================] - 0s 124us/sample - loss: 10.9924
# Epoch 9/1200
# 404/404 [==============================] - 0s 109us/sample - loss: 17.2920
# Epoch 10/1200
# 404/404 [==============================] - 0s 116us/sample - loss: 11.9544
# Epoch 11/1200
# ...

# %%
model.evaluate(x_test, y_test)
# Out:
# 102/102 [==============================] - 0s 3ms/sample - loss: 39.6078
# 39.607766394521676

# %%
# INPUT::
# 1. crim: per capita crime rate by town.
# 2. zn: proportion of residential land zoned for lots over 25,000 sq.ft.
# 3. indus: proportion of non-retail business acres per town.
# 4. chas: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
# 5. nox: nitrogen oxides concentration (parts per 10 million).
# 6. rm: average number of rooms per dwelling.
# 7. age: proportion of owner-occupied units built prior to 1940.
# 8. dis: weighted mean of distances to five Boston employment centres.
# 9. rad: index of accessibility to radial highways.
# 10. tax: full-value property-tax rate per $10,000.
# 11. ptratio: pupil-teacher ratio by town.
# 12. black: 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town.
# 13. lstat: lower status of the population (percent).

# TARGET::
# medv: median value of owner-occupied homes in $1000s.

boston_housing = ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age',
                  'dis', 'rad', 'tax', 'ptratio', 'black', 'lstat']

for i in range(13):
    plt.subplot(3,5,i+1)
    plt.plot(x_train[:,i], y_train, '.')
    plt.title(boston_housing[i])
plt.show()

# %% [markdown]
# ### make the highest price!

# %%
model.predict(np.array([0, 90, 0, 1, 0, 
                        100, 0, 10, 0, 250, 
                        13, 300, 0]).reshape(1,13))
# reshape을 해야 함!!
# Out:
# array([[134.40764]], dtype=float32)

# %%
model.predict(np.array([0,100, 0, 0, 0, 
                        100, 0, 10, 0, 250, 
                        0, 0, 0]).reshape(1,13))
# Out:
# array([[119.713356]], dtype=float32)

# %% [markdown]
# ### make the lowest price!

# %%
model.predict(np.array([100, 10, 25, 0, 1, 
                        50, 100, 0, 25, 700, 
                        23, 0, 30]).reshape(1,13))
# Out:
# array([[12.462951]], dtype=float32)
